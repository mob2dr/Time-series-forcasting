# %% [markdown]
# # Facebook Prophet

# %% [markdown]
# - Prophet works through use of an additive model whereby the non-linear trends in the series are fitted with the appropriate seasonality (whether daily, weekly, or yearly).
# - It is designed to be robust to use and to handle seasonal trends and holidays well, shifts in the trend, and typically handles outliers well
# - Prophet uses a generalized additive model, a type of regression model, to make predictions. It can accomodate non-linear smoothers applied ot the regressors.
# - The model is decomposable into trend, seasonality, and holiday components.
# - Prophet is curve-fitting instead of a model class like ARIMA that explicitly accounts for the temporal component of the model through autoregression.
# - Prophet can accomodate expert information, so it's Bayesian-friendly.
# -  It works best with time series that have strong seasonal effects and several seasons of historical data.

# %% [markdown]
# ## Advantages of Prophet
# - **1.Very fast** - Prophet is very fast. It is used in many applications across Facebook for producing reliable forecasts for planning and goal setting.
#
#
# - **2. Fully automatic** - Prophet is fully automatic. We will get a reasonable forecast on messy data with no manual effort.
#
#
# - **3. Tunable forecasts** - Prophet produces adjustable forecasts. It includes many possibilities for users to tweak and adjust forecasts. We can use human-interpretable parameters to improve the forecast by adding our domain knowledge.
#
#
# - **4. Available in R or Python** - We can implement the Prophet procedure in R or Python.
#
#
#
# - **5. Handles seasonal variations well** - Prophet accommodates seasonality with multiple periods.
#
#
#
# - **6. Robust to outliers** - It is robust to outliers. It handles outliers by removing them.
#
#
#
# - **7. Robust to missing data** - Prophet is resilient to missing data.]
# - **Disadvantages:**
# - Prophet is not a guarantee of perfect forecasting accuracy, and it may not be the best tool for all applications.

# %%
# !pip install --upgrade plotly
# !pip install pystan==2.19.1.1
# !pip install cmdstanpy==0.9.5
# !pip install fbprophe
# Out:
# Requirement already satisfied: plotly in c:\users\badr\anaconda3\lib\site-packages (5.9.0)
# Collecting plotly
#   Downloading plotly-5.14.1-py2.py3-none-any.whl (15.3 MB)
#      --------------------------------------- 15.3/15.3 MB 68.6 kB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\badr\anaconda3\lib\site-packages (from plotly) (21.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\badr\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\badr\anaconda3\lib\site-packages (from packaging->plotly) (3.0.9)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.9.0
#     Uninstalling plotly-5.9.0:
#       Successfully uninstalled plotly-5.9.0
# Successfully installed plotly-5.14.1
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\or_n.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\poly_function.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\poly_function_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\poly_function_traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\remove_typename.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\static_const.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\template_arity.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\template_arity_helper.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\unpack_expr_.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\vararg_matches_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\and_n.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\args.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\basic_expr.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\class_member_traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\deduce_domain_n.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\deep_copy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\expr.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\expr_variadic.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\extends_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\extends_funop_const.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\generate_by_value.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\lambda_matches.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\make_expr.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\make_expr_.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\make_expr_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\matches_.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\memfun_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\or_n.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\poly_function_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\poly_function_traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\template_arity_helper.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\unpack_expr_.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed\vararg_matches_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\detail\preprocessed
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\std.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion\at.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion\pop_back.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion\pop_front.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion\push_back.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion\push_front.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion\reverse.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\fusion
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range\begin.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range\empty.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range\end.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range\rbegin.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range\rend.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range\size.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\range
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\std
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\std\iterator.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\std
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\std\utility.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\functional\std
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\arg.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\call.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\default.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\env.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\fold.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\fold_tree.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\integral_c.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\lazy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\make.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\pass_through.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\when.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\call.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\construct_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\construct_pod_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\default_function_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\expand_pack.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\fold_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\lazy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\make.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\make_gcc_workaround.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\pack.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\pack_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\pass_through_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\when.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\call.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\construct_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\construct_pod_funop.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\default_function_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\expand_pack.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\fold_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\lazy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\make.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\make_gcc_workaround.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\pack_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\pass_through_impl.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed\when.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\proto\transform\detail\preprocessed
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\clone_allocator.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\exception.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\indirect_fun.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\nullable.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_array.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_circular_buffer.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_container.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_deque.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_inserter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_list.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_map.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_map_adapter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_sequence_adapter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_set.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_set_adapter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_unordered_map.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_unordered_set.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\ptr_vector.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_array.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_circular_buffer.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_container.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_deque.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_list.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_map.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_set.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_unordered_map.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_unordered_set.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\serialize_ptr_vector.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\associative_ptr_container.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\default_deleter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\is_convertible.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\map_iterator.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\meta_functions.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\move.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\ptr_container_disable_deprecated.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\reversible_ptr_container.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\scoped_deleter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\serialize_ptr_map_adapter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\serialize_reversible_cont.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\serialize_xml_names.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\static_move_ptr.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\throw_exception.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail\void_ptr_iterator.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\ptr_container\detail
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\arg_from_python.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\args.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\args_fwd.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\back_reference.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\base_type_traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\bases.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\borrowed.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\call.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\call_method.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\cast.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\class.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\class_fwd.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\copy_const_reference.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\copy_non_const_reference.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\data_members.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\def.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\def_visitor.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\default_call_policies.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\dict.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\docstring_options.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\enum.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\errors.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\exception_translator.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\exec.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\extract.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\handle.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\handle_fwd.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\has_back_reference.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\implicit.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\import.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\init.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\instance_holder.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\iterator.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\list.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\long.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\lvalue_from_pytype.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\make_constructor.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\make_function.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\manage_new_object.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\module.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\module_init.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\numpy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_attributes.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_call.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_core.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_fwd.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_items.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_operators.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_protocol.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_protocol_core.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\object_slices.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\opaque_pointer_converter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\operators.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\other.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\overloads.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\override.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\pointee.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\proxy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\ptr.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\pure_virtual.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\raw_function.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\refcount.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\reference_existing_object.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\register_ptr_to_python.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\return_arg.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\return_by_value.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\return_internal_reference.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\return_opaque_pointer.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\return_value_policy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\scope.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\self.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\signature.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\slice.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\slice_nil.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\ssize_t.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\stl_iterator.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\str.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\tag.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\to_python_converter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\to_python_indirect.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\to_python_value.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\tuple.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\type_id.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\with_custodian_and_ward.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\wrapper.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python
#   creating build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\arg_from_python.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\arg_to_python.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\arg_to_python_base.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\as_to_python_function.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\builtin_converters.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\constructor_function.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\context_result_converter.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\convertible_function.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\from_python.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\implicit.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\obj_mgr_arg_from_python.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\object_manager.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\pointer_type_id.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\pyobject_traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\pyobject_type.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\pytype_function.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\pytype_object_mgr_traits.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\registered.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\registered_pointee.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
#   copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter\registrations.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\python\converter
# ...
#   copying pystan\stan\src\stan\mcmc\hmc\static_uniform\adapt_softabs_static_uniform.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\static_uniform
#   copying pystan\stan\src\stan\mcmc\hmc\static_uniform\adapt_unit_e_static_uniform.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\static_uniform
#   copying pystan\stan\src\stan\mcmc\hmc\static_uniform\base_static_uniform.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\static_uniform
#   copying pystan\stan\src\stan\mcmc\hmc\static_uniform\dense_e_static_uniform.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\static_uniform
#   copying pystan\stan\src\stan\mcmc\hmc\static_uniform\diag_e_static_uniform.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\static_uniform
#   copying pystan\stan\src\stan\mcmc\hmc\static_uniform\softabs_static_uniform.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\static_uniform
#   copying pystan\stan\src\stan\mcmc\hmc\static_uniform\unit_e_static_uniform.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\static_uniform
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\adapt_dense_e_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\adapt_diag_e_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\adapt_softabs_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\adapt_unit_e_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\base_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\dense_e_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\diag_e_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\softabs_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   copying pystan\stan\src\stan\mcmc\hmc\xhmc\unit_e_xhmc.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\mcmc\hmc\xhmc
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\finite_diff_grad.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\grad_hess_log_prob.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\grad_tr_mat_times_hessian.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\gradient.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\gradient_dot_vector.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\hessian.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\hessian_times_vector.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\indexing.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\log_prob_grad.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\log_prob_propto.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\model_functional.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\model_header.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\prob_grad.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\standalone_functions_header.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   copying pystan\stan\src\stan\model\test_gradients.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\deep_copy.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\index.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\index_list.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\lvalue.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\rvalue.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\rvalue_at.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\rvalue_index_size.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   copying pystan\stan\src\stan\model\indexing\rvalue_return.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\model\indexing
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\optimization
#   copying pystan\stan\src\stan\optimization\bfgs.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\optimization
#   copying pystan\stan\src\stan\optimization\bfgs_linesearch.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\optimization
#   copying pystan\stan\src\stan\optimization\bfgs_update.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\optimization
#   copying pystan\stan\src\stan\optimization\lbfgs_update.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\optimization
#   copying pystan\stan\src\stan\optimization\newton.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\optimization
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services
#   copying pystan\stan\src\stan\services\error_codes.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\diagnose
#   copying pystan\stan\src\stan\services\diagnose\defaults.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\diagnose
#   copying pystan\stan\src\stan\services\diagnose\diagnose.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\diagnose
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\experimental
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\experimental\advi
#   copying pystan\stan\src\stan\services\experimental\advi\defaults.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\experimental\advi
#   copying pystan\stan\src\stan\services\experimental\advi\fullrank.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\experimental\advi
#   copying pystan\stan\src\stan\services\experimental\advi\meanfield.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\experimental\advi
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\optimize
#   copying pystan\stan\src\stan\services\optimize\bfgs.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\optimize
#   copying pystan\stan\src\stan\services\optimize\defaults.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\optimize
#   copying pystan\stan\src\stan\services\optimize\lbfgs.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\optimize
#   copying pystan\stan\src\stan\services\optimize\newton.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\optimize
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\defaults.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\fixed_param.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_nuts_dense_e.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_nuts_dense_e_adapt.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_nuts_diag_e.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_nuts_diag_e_adapt.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_nuts_unit_e.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_nuts_unit_e_adapt.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_static_dense_e.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_static_dense_e_adapt.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_static_diag_e.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_static_diag_e_adapt.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_static_unit_e.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\hmc_static_unit_e_adapt.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   copying pystan\stan\src\stan\services\sample\standalone_gqs.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\sample
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\create_rng.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\create_unit_e_dense_inv_metric.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\create_unit_e_diag_inv_metric.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\experimental_message.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\generate_transitions.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\gq_writer.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\initialize.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\inv_metric.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\mcmc_writer.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\read_dense_inv_metric.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\read_diag_inv_metric.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\run_adaptive_sampler.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\run_sampler.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\validate_dense_inv_metric.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   copying pystan\stan\src\stan\services\util\validate_diag_inv_metric.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\services\util
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\variational
#   copying pystan\stan\src\stan\variational\advi.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\variational
#   copying pystan\stan\src\stan\variational\base_family.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\variational
#   copying pystan\stan\src\stan\variational\print_progress.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\variational
#   creating build\lib.win-amd64-cpython-39\pystan\stan\src\stan\variational\families
#   copying pystan\stan\src\stan\variational\families\normal_fullrank.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\variational\families
#   copying pystan\stan\src\stan\variational\families\normal_meanfield.hpp -> build\lib.win-amd64-cpython-39\pystan\stan\src\stan\variational\families
#   creating build\lib.win-amd64-cpython-39\pystan\tests\data
#   copying pystan\tests\data\blocker.1.csv -> build\lib.win-amd64-cpython-39\pystan\tests\data
#   copying pystan\tests\data\blocker.2.csv -> build\lib.win-amd64-cpython-39\pystan\tests\data
#   copying pystan\tests\data\external1.stan -> build\lib.win-amd64-cpython-39\pystan\tests\data
#   copying pystan\tests\data\external2.stan -> build\lib.win-amd64-cpython-39\pystan\tests\data
#   running build_ext
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   building 'pystan._api' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# pystan
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# Collecting pystan==2.19.1.1
#   Downloading pystan-2.19.1.1.tar.gz (16.2 MB)
#      --------------------------------------- 16.2/16.2 MB 55.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in c:\users\badr\anaconda3\lib\site-packages (from pystan==2.19.1.1) (0.29.32)
# Requirement already satisfied: numpy>=1.7 in c:\users\badr\anaconda3\lib\site-packages (from pystan==2.19.1.1) (1.23.5)
# Building wheels for collected packages: pystan
#   Building wheel for pystan (setup.py): started
#   Building wheel for pystan (setup.py): still running...
#   Building wheel for pystan (setup.py): finished with status 'error'
#   Running setup.py clean for pystan
# Failed to build pystan
# Installing collected packages: pystan
#   Running setup.py install for pystan: started
#   Running setup.py install for pystan: finished with status 'error'
# Collecting cmdstanpy==0.9.5
#   Downloading cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy in c:\users\badr\anaconda3\lib\site-packages (from cmdstanpy==0.9.5) (1.23.5)
# Requirement already satisfied: pandas in c:\users\badr\anaconda3\lib\site-packages (from cmdstanpy==0.9.5) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\badr\anaconda3\lib\site-packages (from pandas->cmdstanpy==0.9.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\badr\anaconda3\lib\site-packages (from pandas->cmdstanpy==0.9.5) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\badr\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas->cmdstanpy==0.9.5) (1.12.0)
# Installing collected packages: cmdstanpy
# Successfully installed cmdstanpy-0.9.5
# ERROR: Could not find a version that satisfies the requirement fbprophe (from versions: none)
# ERROR: No matching distribution found for fbprophe

# %%
# import prophet libraries
from fbprophet import Prophet
from fbprophet.diagnostics import performance_metrics
from fbprophet.diagnostics import cross_validation

# %%
peyton = pd.read_csv('AirPassengers.csv')

# %%
plt.plot(peyton['Month'], peyton['Passengers'])

# %%
df_air=peyton.copy()
peyton_test=peyton[120:]
peyton=peyton[:120]

# %% [markdown]
# We fit the model by instantiating a new Prophet object. Any settings to the forecasting procedure are passed into the constructor. Then you call its fit method and pass in the historical dataframe. Fitting should take 1-5 seconds.

# %%
prophet_model = Prophet()
prophet_model.fit(peyton)

# %%
# Prophet's make_future_dataframe method makes a DataFrame that includes the historical data, as well as the predictions.
future = prophet_model.make_future_dataframe(periods=24, freq='m')
future.tail()

# %% [markdown]
# The predict method will assign each row in future a predicted value which it names yhat. If you pass in historical dates, it will provide an in-sample fit. The forecast object here is a new dataframe that includes a column yhat with the forecast, as well as columns for components and uncertainty intervals.

# %%
forecast = prophet_model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %% [markdown]
# - **ds**: the datestamp of the forecasted value
# - **yhat**: the forecasted value of our metric (in Statistics, yhat is a notation traditionally used to represent the predicted values of a value y)
# - **yhat_lower**: the lower bound of our forecasts
# - **yhat_upper**: the upper bound of our forecasts

# %% [markdown]
# You can plot the forecast by calling the Prophet.plot method and passing in your forecast dataframe.

# %%
fig1 = prophet_model.plot(forecast)

# %% [markdown]
# If you want to see the forecast components, you can use the Prophet.plot_components method. By default you’ll see the trend, yearly seasonality, and weekly seasonality of the time series. If you include holidays, you’ll see those here, too.

# %%
# So, Let's decompose this graph into the trend and seasonality.
fig2 = prophet_model.plot_components(forecast)

# %% [markdown]
# It looks like the latter seasonal high and low data points in the training data weren't picked up super well. Perhpas we should try making that seasonality effect multiplicative.

# %% [markdown]
# # Model evaluation

# %%
evaluate(peyton['y'], forecast['yhat'])

# %%
# Evaluate the model's performance on test data using cross-validation
df_cv = cross_validation(prophet_model, horizon='24 day', period='30 day', 
                         initial=str(len(peyton))+' days')
df_p = performance_metrics(df_cv)
print(df_p)

# %% [markdown]
# ## As we saw that the additive model doesn't fit the data well, So, let's try the multiplicative model.

# %%
prophet_model = Prophet(seasonality_mode='multiplicative')
prophet_model.fit(peyton)

# %% [markdown]
# An interactive figure of the forecast and components can be created with plotly. You will need to install plotly 4.0 or above separately, as it will not by default be installed with prophet. You will also need to install the notebook and ipywidgets packages.

# %%
# Prophet's make_future_dataframe method makes a DataFrame that includes the historical data, as well as the predictions.
future = prophet_model.make_future_dataframe(periods=24, freq='m')
future.tail()

# %%
forecast = prophet_model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
fig1 = prophet_model.plot(forecast)

# %%
# So, Let's decompose this graph into the trend and seasonality.
fig2 = prophet_model.plot_components(forecast)

# %% [markdown]
# Looks like people travel in the summer.

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly

plot_plotly(prophet_model, forecast)

# %%
plot_components_plotly(prophet_model, forecast)

# %% [markdown]
# ## Model evaluation

# %%
# Evaluate the model's performance on test data using cross-validation
df_cv = cross_validation(prophet_model, horizon='24 day', period='30 day', 
                         initial=str(len(peyton))+' days')
df_p = performance_metrics(df_cv)
print(df_p)

# %%
peyton['y']=np.log(peyton['y'])
prophet_model = Prophet()
prophet_model.fit(peyton)
forecast = prophet_model.predict(future)
fig1 = prophet_model.plot(forecast)

# %%
# So, Let's decompose this graph into the trend and seasonality.
fig2 = prophet_model.plot_components(forecast)

# %%
plot_plotly(prophet_model, forecast)

# %% [markdown]
# Prophet respectively, the errors are significantly lower than the errors obtained with ARIMA.

# %% [markdown]
# ## Model evaluation

# %%
evaluate(peyton['y'], forecast['yhat'])

# %%
# Evaluate the model's performance on test data using cross-validation
df_cv = cross_validation(prophet_model, horizon='24 day', period='30 day', 
                         initial=str(len(peyton))+' days')
df_p = performance_metrics(df_cv)
print(df_p)

# %% [markdown]
# the model with the multiplicative seasonality effect performs compared to a persistence model. and the model after data log transforming is more effecient.
